# %%
import sys
print(sys.executable)

# !pip3.10 install numpy
# !pip3.10 install tenacity
# !pip3.10 install pandas
# !pip3.10 install tiktoken
# !pip3.10 install  matplotlib
# plotly, scipy, sklearn, scikit-learn
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10

# %%
import openai
from dotenv import dotenv_values
config = dotenv_values("/Users/julianboyce/Documents/work/gpt/.env")
openai.api_key = config["OPENAI_API_KEY"]

# %%
# Sanity check your api key is here
####### print(openai.api_key)

# %%
import pandas as pd
import numpy as np
from tenacity import retry, wait_random_exponential, stop_after_attempt
import pickle
import tiktoken

# %% [markdown]
# ## Load The Movie Data
#
# Reference: https://www.udemy.com/course/mastering-openai/learn/lecture/37398616#overview
#
# You can download the entire movie set found here at [Movie Plots](https://www.kaggle.com/datasets/jrobischon/wikipedia-movie-plots) from kaggle.com
#
# Store this under the file name: wiki_movie_plots_deduped.csv

# %%
dataset_path = "./wiki_movie_plots_deduped.csv"
df = pd.read_csv(dataset_path)

# %%
# Narrow our data set to 500 recent American movies (!!!to save money!!!)
movies = df[df["Origin/Ethnicity"] == "American"].sort_values("Release Year", ascending=False).head(1000)

# %%
movies
# Out:
#        Release Year                      Title Origin/Ethnicity  \
# 17376          2017             Phantom Thread         American
# 17243          2017     Everything, Everything         American
# 17241          2017            Alien: Covenant         American
# 17240          2017             Paris Can Wait         American
# 17239          2017                   The Wall         American
# ...             ...                        ...              ...
# 16217          2012  Celeste and Jesse Forever         American
# 16246          2012                   Deadline         American
# 16216          2012           Casa de Mi Padre         American
# 16245          2012                   Deadfall         American
# 16264          2012                  Evil Head         American
#
#                    Director  \
# 17376  Paul Thomas Anderson
# 17243         Stella Meghie
# 17241          Ridley Scott
# 17240       Eleanor Coppola
# 17239            Doug Liman
# ...                     ...
# 16217    Lee Toland Krieger
# 16246             Curt Hahn
# 16216         Matt Piedmont
# 16245     Stefan Ruzowitzky
# 16264          Doug Sakmann
#
#                                                     Cast            Genre  \
# 17376  Paul Thomas Anderson (director/screenplay); Da...            drama
# 17243  Stella Meghie (director); J. Mills Goodloe (sc...   romance, drama
# 17241  Ridley Scott (director); Michael Green, Jack P...   sci-fi, horror
# 17240  Eleanor Coppola (director/screenplay); Diane L...  comedy, romance
# 17239  Doug Liman (director); Dwain Worrell (screenpl...  drama, thriller
# ...                                                  ...              ...
# 16217  Rashida Jones, Andy Samberg, Chris Messina, Ar...  romantic comedy
# 16246  Eric Roberts, Steve Talley, J.D. Souther, Davi...            drama
# 16216  Will Ferrell, Gael García Bernal, Diego Luna, ...           comedy
# 16245  Eric Bana, Olivia Wilde, Jason Cavalier, Charl...            drama
# 16264  Joanna Angel, Tommy Pistol, Veruca James, Dann...           horror
#
#                                                Wiki Page  \
# 17376       https://en.wikipedia.org/wiki/Phantom_Thread
# 17243  https://en.wikipedia.org/wiki/Everything,_Ever...
# 17241      https://en.wikipedia.org/wiki/Alien:_Covenant
# 17240       https://en.wikipedia.org/wiki/Paris_Can_Wait
# 17239  https://en.wikipedia.org/wiki/The_Wall_(2017_f...
# ...                                                  ...
# 16217  https://en.wikipedia.org/wiki/Celeste_and_Jess...
# 16246  https://en.wikipedia.org/wiki/Deadline_(2012_f...
# 16216     https://en.wikipedia.org/wiki/Casa_de_Mi_Padre
# 16245  https://en.wikipedia.org/wiki/Deadfall_(2012_f...
# 16264            https://en.wikipedia.org/wiki/Evil_Head
#
#                                                     Plot
# 17376  In 1954 London, renowned fashion designer Reyn...
# 17243  Eighteen-year-old Maddy suffers from SCID, an ...
# 17241  In a prologue, business magnate Peter Weyland ...
# 17240  Anne (Diane Lane) is in Cannes with her husban...
# 17239  During the Iraq War, U.S. Army Staff Sergeant ...
# ...                                                  ...
# 16217  Celeste (Rashida Jones) and Jesse (Andy Samber...
# 16246  Young newsparer reporter Matt Harper (Steve Ta...
# 16216  Armando Álvarez (Will Ferrell) has lived and w...
# 16245  After a casino heist gone wrong, siblings Addi...
# 16264  For their vacation, Ash, his wife Linda, their...
#
# [1000 rows x 8 columns]

# %%
# Extract the movie plots into a list
movie_plots = movies["Plot"].values

# %% [markdown]
# ## Generating The Embeddings

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def get_embedding(text, model="text-embedding-ada-002"):

    # replace newlines, which can negatively affect performance.
    text = text.replace("\n", " ")

    return openai.Embedding.create(input=text, model=model)["data"][0]["embedding"]

# %%
enc = tiktoken.encoding_for_model("text-embedding-ada-002")

# %%
total_tokens = sum([len(enc.encode(plot)) for plot in movie_plots])

# %%
total_tokens
cost = total_tokens * (.0004 / 1000)
print(f"Estimated cost ${cost:.2f}")
# Out:
# Estimated cost $0.30

# %% [markdown]
# ## TODO: Instead of storing this to a file you should persist this to a vector database

# %%
# establish a cache of embeddings to avoid recomputing
# cache is a dict of tuples (text, model) -> embedding, saved as a pickle file

# set path to embedding cache
embedding_cache_path = "movie_embeddings_cache2.pkl"

# load the cache if it exists, and save a copy to disk
try:
    embedding_cache = pd.read_pickle(embedding_cache_path)
except FileNotFoundError:
    embedding_cache = {}
with open(embedding_cache_path, "wb") as embedding_cache_file:
    pickle.dump(embedding_cache, embedding_cache_file)

# define a function to retrieve embeddings from the cache if present, and otherwise request via the API
def embedding_from_string(
    string,
    model="text-embedding-ada-002",
    embedding_cache=embedding_cache
):
    """Return embedding of given string, using a cache to avoid recomputing."""
    if (string, model) not in embedding_cache.keys():
        embedding_cache[(string, model)] = get_embedding(string, model)
        print(f"GOT EMBEDDING FROM OPENAI FOR {string[:20]}")
        with open(embedding_cache_path, "wb") as embedding_cache_file:
            pickle.dump(embedding_cache, embedding_cache_file)
    return embedding_cache[(string, model)]

# %%
# This line actaully generates the embeddings
plot_embeddings = [embedding_from_string(plot, model="text-embedding-ada-002") for plot in movie_plots]
# Out:
# GOT EMBEDDING FROM OPENAI FOR In 1954 London, reno
# GOT EMBEDDING FROM OPENAI FOR Eighteen-year-old Ma
# GOT EMBEDDING FROM OPENAI FOR In a prologue, busin
# GOT EMBEDDING FROM OPENAI FOR Anne (Diane Lane) is
# GOT EMBEDDING FROM OPENAI FOR During the Iraq War,
# GOT EMBEDDING FROM OPENAI FOR A contemporary tale
# GOT EMBEDDING FROM OPENAI FOR Recently fired from
# GOT EMBEDDING FROM OPENAI FOR The movie opens with
# GOT EMBEDDING FROM OPENAI FOR Mary (Debra Winger)
# GOT EMBEDDING FROM OPENAI FOR In 2014, Peter Quill
# GOT EMBEDDING FROM OPENAI FOR A young street magic
# GOT EMBEDDING FROM OPENAI FOR Having made a career
# GOT EMBEDDING FROM OPENAI FOR When her car breaks
# GOT EMBEDDING FROM OPENAI FOR Mikael (Oscar Isaac)
# GOT EMBEDDING FROM OPENAI FOR Julia Banks is being
# GOT EMBEDDING FROM OPENAI FOR This documentary fol
# GOT EMBEDDING FROM OPENAI FOR Best friends Mindy (
# GOT EMBEDDING FROM OPENAI FOR Dash (voiced by Schw
# GOT EMBEDDING FROM OPENAI FOR Ireland, 1905: Percy
# GOT EMBEDDING FROM OPENAI FOR Thirteen years ago,
# GOT EMBEDDING FROM OPENAI FOR Dominic "Dom" Torett
# GOT EMBEDDING FROM OPENAI FOR Roman Melnyk, a cons
# GOT EMBEDDING FROM OPENAI FOR In a small town near
# GOT EMBEDDING FROM OPENAI FOR Gloria is an unemplo
# GOT EMBEDDING FROM OPENAI FOR Joe, Willie, and Alb
# GOT EMBEDDING FROM OPENAI FOR One year after the p
# GOT EMBEDDING FROM OPENAI FOR The story is told fr
# GOT EMBEDDING FROM OPENAI FOR In 1980, atheist and
# GOT EMBEDDING FROM OPENAI FOR In Emerald Bay, Flor
# GOT EMBEDDING FROM OPENAI FOR During their visit t
# GOT EMBEDDING FROM OPENAI FOR Former villain Gru i
# GOT EMBEDDING FROM OPENAI FOR In 2007, self-define
# GOT EMBEDDING FROM OPENAI FOR Baby is a getaway dr
# GOT EMBEDDING FROM OPENAI FOR In an unspecified ne
# GOT EMBEDDING FROM OPENAI FOR Kumail is a comedian
# GOT EMBEDDING FROM OPENAI FOR Martha Farnsworth ru
# GOT EMBEDDING FROM OPENAI FOR In 484 AD, King Arth
# GOT EMBEDDING FROM OPENAI FOR In a small suburban
# GOT EMBEDDING FROM OPENAI FOR Lisa (Mandy Moore) a
# GOT EMBEDDING FROM OPENAI FOR At the Clinton Corre
# GOT EMBEDDING FROM OPENAI FOR In 2006, four friend
# GOT EMBEDDING FROM OPENAI FOR Lightning McQueen, n
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Megan Leavey is a US
# GOT EMBEDDING FROM OPENAI FOR After the young boy
# GOT EMBEDDING FROM OPENAI FOR A highly contagious
# GOT EMBEDDING FROM OPENAI FOR In 1157 A.D., severa
# GOT EMBEDDING FROM OPENAI FOR Dean (Demetri Martin
# GOT EMBEDDING FROM OPENAI FOR In the city of Piqua
# GOT EMBEDDING FROM OPENAI FOR In present-day Paris
# GOT EMBEDDING FROM OPENAI FOR In the summer of 200
# GOT EMBEDDING FROM OPENAI FOR Twelve-year-old Henr
# GOT EMBEDDING FROM OPENAI FOR In Smurf Village, th
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR While holding a cryi
# GOT EMBEDDING FROM OPENAI FOR Young Gitty, an 11-y
# GOT EMBEDDING FROM OPENAI FOR At a large financial
# GOT EMBEDDING FROM OPENAI FOR Searching for the se
# GOT EMBEDDING FROM OPENAI FOR Four days after the
# GOT EMBEDDING FROM OPENAI FOR After Anastasia Stee
# GOT EMBEDDING FROM OPENAI FOR Within the Lego Univ
# GOT EMBEDDING FROM OPENAI FOR Growing Up Smith is
# GOT EMBEDDING FROM OPENAI FOR A man is tasked with
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR On an airplane bound
# GOT EMBEDDING FROM OPENAI FOR Living in a gang rid
# GOT EMBEDDING FROM OPENAI FOR Dr. James Marcus, th
# GOT EMBEDDING FROM OPENAI FOR In the 1950s, a fera
# GOT EMBEDDING FROM OPENAI FOR Set in the autumn of
# GOT EMBEDDING FROM OPENAI FOR To give a better fut
# GOT EMBEDDING FROM OPENAI FOR Former child star Ga
# GOT EMBEDDING FROM OPENAI FOR NSA Agent Augustus G
# GOT EMBEDDING FROM OPENAI FOR Casey Cooke is an em
# GOT EMBEDDING FROM OPENAI FOR After the accidental
# GOT EMBEDDING FROM OPENAI FOR The film centers on
# GOT EMBEDDING FROM OPENAI FOR In Las Vegas, vice L
# GOT EMBEDDING FROM OPENAI FOR In 1969, a mass murd
# GOT EMBEDDING FROM OPENAI FOR Terravex Oil is in t
# GOT EMBEDDING FROM OPENAI FOR The remaining vampir
# GOT EMBEDDING FROM OPENAI FOR It is the last day b
# GOT EMBEDDING FROM OPENAI FOR Directed by Sofia Ca
# GOT EMBEDDING FROM OPENAI FOR In February, at a pr
# GOT EMBEDDING FROM OPENAI FOR Sarah (Riley Keough)
# GOT EMBEDDING FROM OPENAI FOR Dr. Jan Żabiński (Jo
# GOT EMBEDDING FROM OPENAI FOR A man named Tim Temp
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR In the Cenozoic era,
# GOT EMBEDDING FROM OPENAI FOR Late at night in a c
# GOT EMBEDDING FROM OPENAI FOR In Austin, Texas, Fa
# GOT EMBEDDING FROM OPENAI FOR Mike Milch (John Gal
# GOT EMBEDDING FROM OPENAI FOR A beautiful enchantr
# GOT EMBEDDING FROM OPENAI FOR Five young men pledg
# GOT EMBEDDING FROM OPENAI FOR In 1944, in the mids
# GOT EMBEDDING FROM OPENAI FOR A Manhattanite banke
# GOT EMBEDDING FROM OPENAI FOR The film opens showi
# GOT EMBEDDING FROM OPENAI FOR Eloise McGarry atten
# GOT EMBEDDING FROM OPENAI FOR Samantha Kingston wa
# GOT EMBEDDING FROM OPENAI FOR Mackenzie "Mack" Phi
# GOT EMBEDDING FROM OPENAI FOR In 2029, no mutants
# GOT EMBEDDING FROM OPENAI FOR Nursing assistant Ru
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR Casey, an American l
# GOT EMBEDDING FROM OPENAI FOR Bodi (Luke Wilson) i
# GOT EMBEDDING FROM OPENAI FOR African-American pho
# GOT EMBEDDING FROM OPENAI FOR In the year 1347 in
# GOT EMBEDDING FROM OPENAI FOR Mordred, an iron-fis
# GOT EMBEDDING FROM OPENAI FOR The movie starts wit
# GOT EMBEDDING FROM OPENAI FOR In "9 months B.C.",
# GOT EMBEDDING FROM OPENAI FOR Derek Cho, the film'
# GOT EMBEDDING FROM OPENAI FOR In the town of Ebbin
# GOT EMBEDDING FROM OPENAI FOR The story centers ar
# GOT EMBEDDING FROM OPENAI FOR After finally becomi
# GOT EMBEDDING FROM OPENAI FOR In 1934, famous Belg
# GOT EMBEDDING FROM OPENAI FOR Christine "Lady Bird
# GOT EMBEDDING FROM OPENAI FOR In 2003, Larry "Doc"
# GOT EMBEDDING FROM OPENAI FOR Amy (Mila Kunis) is
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR Teenager Belle Walke
# GOT EMBEDDING FROM OPENAI FOR The plot tells the s
# GOT EMBEDDING FROM OPENAI FOR This is a story of t
# GOT EMBEDDING FROM OPENAI FOR Criminal Edgar Munse
# GOT EMBEDDING FROM OPENAI FOR In 1959, the peacefu
# GOT EMBEDDING FROM OPENAI FOR After a harrowing 15
# GOT EMBEDDING FROM OPENAI FOR Steven Murphy, a ski
# GOT EMBEDDING FROM OPENAI FOR The film interlaces
# GOT EMBEDDING FROM OPENAI FOR At the Sawyer homest
# GOT EMBEDDING FROM OPENAI FOR After Ron Hall (Greg
# GOT EMBEDDING FROM OPENAI FOR The film opens after
# GOT EMBEDDING FROM OPENAI FOR Eric "Supe" Marsh, t
# GOT EMBEDDING FROM OPENAI FOR In 2019, following m
# GOT EMBEDDING FROM OPENAI FOR During a weekend exc
# GOT EMBEDDING FROM OPENAI FOR Thousands of years a
# GOT EMBEDDING FROM OPENAI FOR August "Auggie" Pull
# GOT EMBEDDING FROM OPENAI FOR The film begins duri
# GOT EMBEDDING FROM OPENAI FOR Emily Martin (Noël W
# GOT EMBEDDING FROM OPENAI FOR Molly Bloom is world
# GOT EMBEDDING FROM OPENAI FOR In 1973, 16-year-old
# GOT EMBEDDING FROM OPENAI FOR In 1892, settler Wes
# GOT EMBEDDING FROM OPENAI FOR The granddaughter of
# GOT EMBEDDING FROM OPENAI FOR In an alternate pres
# GOT EMBEDDING FROM OPENAI FOR In 1966 Vietnam, Sta
# GOT EMBEDDING FROM OPENAI FOR Kyle (Wilson) and Pe
# GOT EMBEDDING FROM OPENAI FOR In the future, searc
# GOT EMBEDDING FROM OPENAI FOR Three years after th
# GOT EMBEDDING FROM OPENAI FOR P. T. Barnum and his
# GOT EMBEDDING FROM OPENAI FOR In 1996 in Brantford
# GOT EMBEDDING FROM OPENAI FOR Mark Corley, a Los A
# GOT EMBEDDING FROM OPENAI FOR In Spain, a ranch ow
# GOT EMBEDDING FROM OPENAI FOR Shortly after the ba
# GOT EMBEDDING FROM OPENAI FOR Defense lawyer Duke,
# GOT EMBEDDING FROM OPENAI FOR In 1970s Portland, O
# GOT EMBEDDING FROM OPENAI FOR Mickey Rubin, a Cone
# GOT EMBEDDING FROM OPENAI FOR Elisa Esposito, who
# GOT EMBEDDING FROM OPENAI FOR A musician lives wit
# GOT EMBEDDING FROM OPENAI FOR Elio, a 17-year-old
# GOT EMBEDDING FROM OPENAI FOR In May 1940, the opp
# GOT EMBEDDING FROM OPENAI FOR In Santa Cecilia, Me
# GOT EMBEDDING FROM OPENAI FOR Roman J. Israel (Den
# GOT EMBEDDING FROM OPENAI FOR The story is told in
# GOT EMBEDDING FROM OPENAI FOR San Francisco, 1998:
# GOT EMBEDDING FROM OPENAI FOR Robin Cavendish fall
# GOT EMBEDDING FROM OPENAI FOR Frankie (Harris Dick
# GOT EMBEDDING FROM OPENAI FOR Patricia "Dumbo" Dom
# GOT EMBEDDING FROM OPENAI FOR Jimmy Logan is laid
# GOT EMBEDDING FROM OPENAI FOR Private UK-based bod
# GOT EMBEDDING FROM OPENAI FOR Thomas Webb (Callum
# GOT EMBEDDING FROM OPENAI FOR Ingrid Thorburn is a
# GOT EMBEDDING FROM OPENAI FOR Connie Nikas forcibl
# GOT EMBEDDING FROM OPENAI FOR Surly Squirrel is no
# GOT EMBEDDING FROM OPENAI FOR The unconventional,
# GOT EMBEDDING FROM OPENAI FOR In 1943, dollmaker S
# GOT EMBEDDING FROM OPENAI FOR A team of trained op
# GOT EMBEDDING FROM OPENAI FOR During a winter seas
# GOT EMBEDDING FROM OPENAI FOR Karla Dyson (Halle B
# GOT EMBEDDING FROM OPENAI FOR Eleven-year-old Jake
# GOT EMBEDDING FROM OPENAI FOR James lives in an un
# GOT EMBEDDING FROM OPENAI FOR On July 23, 1967, th
# GOT EMBEDDING FROM OPENAI FOR Gene is an emoji tha
# GOT EMBEDDING FROM OPENAI FOR Wall Street broker W
# GOT EMBEDDING FROM OPENAI FOR Four lifelong best f
# GOT EMBEDDING FROM OPENAI FOR In the 28th century,
# GOT EMBEDDING FROM OPENAI FOR Clare Shannon, a 17-
# GOT EMBEDDING FROM OPENAI FOR Two years have passe
# GOT EMBEDDING FROM OPENAI FOR Following the Battle
# GOT EMBEDDING FROM OPENAI FOR In 1940, Thurgood Ma
# GOT EMBEDDING FROM OPENAI FOR Based on a true stor
# GOT EMBEDDING FROM OPENAI FOR Menashe (Menashe Lus
# GOT EMBEDDING FROM OPENAI FOR Set in the Netherlan
# GOT EMBEDDING FROM OPENAI FOR The film dramatizes
# GOT EMBEDDING FROM OPENAI FOR Theresa "Tree" Gelbm
# GOT EMBEDDING FROM OPENAI FOR After an operation i
# GOT EMBEDDING FROM OPENAI FOR Former boxer and dru
# GOT EMBEDDING FROM OPENAI FOR Six-year-old Moonee
# GOT EMBEDDING FROM OPENAI FOR The ponies of Equest
# GOT EMBEDDING FROM OPENAI FOR In January, after th
# GOT EMBEDDING FROM OPENAI FOR A medical student, C
# GOT EMBEDDING FROM OPENAI FOR In the late 1970s, B
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Abdul Karim, a young
# GOT EMBEDDING FROM OPENAI FOR Theresa provides her
# GOT EMBEDDING FROM OPENAI FOR In 2049, replicants
# GOT EMBEDDING FROM OPENAI FOR Jeff Bauman is a wel
# GOT EMBEDDING FROM OPENAI FOR A young boy ventures
# GOT EMBEDDING FROM OPENAI FOR A year after the eve
# GOT EMBEDDING FROM OPENAI FOR Brad Sloan (Ben Stil
# GOT EMBEDDING FROM OPENAI FOR In a large house rec
# GOT EMBEDDING FROM OPENAI FOR On the morning of Se
# GOT EMBEDDING FROM OPENAI FOR Mitch Rapp and his g
# GOT EMBEDDING FROM OPENAI FOR In October 1988, Bil
# GOT EMBEDDING FROM OPENAI FOR Aging rock star Turk
# GOT EMBEDDING FROM OPENAI FOR Three Catholic pries
# GOT EMBEDDING FROM OPENAI FOR Davis is a successfu
# GOT EMBEDDING FROM OPENAI FOR Waking inside a labo
# GOT EMBEDDING FROM OPENAI FOR Mowgli is a "man cub
# GOT EMBEDDING FROM OPENAI FOR Will drives with his
# GOT EMBEDDING FROM OPENAI FOR Adapted from Sony Cl
# GOT EMBEDDING FROM OPENAI FOR To survive harsh eco
# GOT EMBEDDING FROM OPENAI FOR The story follows Mi
# GOT EMBEDDING FROM OPENAI FOR In Texas in the fall
# GOT EMBEDDING FROM OPENAI FOR Carl Black and his f
# GOT EMBEDDING FROM OPENAI FOR AP History teacher G
# GOT EMBEDDING FROM OPENAI FOR In a motel, Roy Toml
# GOT EMBEDDING FROM OPENAI FOR Toula Portokalos-Mil
# GOT EMBEDDING FROM OPENAI FOR Eighteen months afte
# GOT EMBEDDING FROM OPENAI FOR Former gymnastics Br
# GOT EMBEDDING FROM OPENAI FOR Pat, Sam, Reece and
# GOT EMBEDDING FROM OPENAI FOR When Spanish industr
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR Evil sorceress Queen
# GOT EMBEDDING FROM OPENAI FOR On Bird Island, an i
# GOT EMBEDDING FROM OPENAI FOR 26-year-old Louisa C
# GOT EMBEDDING FROM OPENAI FOR Set in Burleson, Tex
# GOT EMBEDDING FROM OPENAI FOR Two years after thei
# GOT EMBEDDING FROM OPENAI FOR Chapter One – Lookin
# GOT EMBEDDING FROM OPENAI FOR En Sabah Nur, a powe
# GOT EMBEDDING FROM OPENAI FOR In 1977 Los Angeles,
# GOT EMBEDDING FROM OPENAI FOR In the 1790s, the re
# GOT EMBEDDING FROM OPENAI FOR On the morning of De
# GOT EMBEDDING FROM OPENAI FOR Peter and Bronny Tay
# GOT EMBEDDING FROM OPENAI FOR Flamboyant televisio
# GOT EMBEDDING FROM OPENAI FOR In 1991, the brainwa
# GOT EMBEDDING FROM OPENAI FOR Above planet Tenemul
# GOT EMBEDDING FROM OPENAI FOR As Mother's Day draw
# GOT EMBEDDING FROM OPENAI FOR Smoke and Oil Dresde
# GOT EMBEDDING FROM OPENAI FOR After Evelyn forbids
# GOT EMBEDDING FROM OPENAI FOR Greta Evans, a young
# GOT EMBEDDING FROM OPENAI FOR Doris Miller is a sh
# GOT EMBEDDING FROM OPENAI FOR Jason Kelly is a law
# GOT EMBEDDING FROM OPENAI FOR Jane and her husband
# GOT EMBEDDING FROM OPENAI FOR Bernard "Bernie" Web
# GOT EMBEDDING FROM OPENAI FOR In the spirit realm,
# GOT EMBEDDING FROM OPENAI FOR Physicist Jim Beale,
# GOT EMBEDDING FROM OPENAI FOR In 1959, Ip Man is s
# GOT EMBEDDING FROM OPENAI FOR Ohio high-schooler C
# GOT EMBEDDING FROM OPENAI FOR Norm the polar bear
# GOT EMBEDDING FROM OPENAI FOR Charlie is a playboy
# GOT EMBEDDING FROM OPENAI FOR In 2012, Benghazi, L
# GOT EMBEDDING FROM OPENAI FOR The film starts in M
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Philosophy professor
# GOT EMBEDDING FROM OPENAI FOR The majority of the
# GOT EMBEDDING FROM OPENAI FOR In 1976, paranormal
# GOT EMBEDDING FROM OPENAI FOR In 1951, Eddie Manni
# GOT EMBEDDING FROM OPENAI FOR Early 19th century E
# GOT EMBEDDING FROM OPENAI FOR Travis Shaw (Benjami
# GOT EMBEDDING FROM OPENAI FOR Wade Wilson is a dis
# GOT EMBEDDING FROM OPENAI FOR At Fashion Interpol,
# GOT EMBEDDING FROM OPENAI FOR Alice (Dakota Johnso
# GOT EMBEDDING FROM OPENAI FOR After crushing a Zea
# GOT EMBEDDING FROM OPENAI FOR In 1630s New England
# GOT EMBEDDING FROM OPENAI FOR Jesse Owens, a promi
# GOT EMBEDDING FROM OPENAI FOR In an alternate vers
# GOT EMBEDDING FROM OPENAI FOR In Atlanta, Georgia,
# GOT EMBEDDING FROM OPENAI FOR In a world populated
# GOT EMBEDDING FROM OPENAI FOR Western intelligence
# GOT EMBEDDING FROM OPENAI FOR In 2003 New York Cit
# GOT EMBEDDING FROM OPENAI FOR Sets in the 19th cen
# GOT EMBEDDING FROM OPENAI FOR After breaking up wi
# GOT EMBEDDING FROM OPENAI FOR At the age of 7, whe
# GOT EMBEDDING FROM OPENAI FOR Told in the form of
# GOT EMBEDDING FROM OPENAI FOR Eighteen months afte
# GOT EMBEDDING FROM OPENAI FOR Draenor, the homewor
# GOT EMBEDDING FROM OPENAI FOR In 1879, robber baro
# GOT EMBEDDING FROM OPENAI FOR Set against the ante
# GOT EMBEDDING FROM OPENAI FOR Rachel Watson is an
# GOT EMBEDDING FROM OPENAI FOR In March 1997, Loomi
# GOT EMBEDDING FROM OPENAI FOR On April 20, 2010, D
# GOT EMBEDDING FROM OPENAI FOR For years, Abraham P
# GOT EMBEDDING FROM OPENAI FOR For generations, the
# GOT EMBEDDING FROM OPENAI FOR The film chronicles
# GOT EMBEDDING FROM OPENAI FOR Lee Weathers is a "r
# GOT EMBEDDING FROM OPENAI FOR In 2014, James Donah
# GOT EMBEDDING FROM OPENAI FOR In 2013, Edward Snow
# GOT EMBEDDING FROM OPENAI FOR On her 43rd birthday
# GOT EMBEDDING FROM OPENAI FOR Looking for a fresh
# GOT EMBEDDING FROM OPENAI FOR On a tiny isolated S
# GOT EMBEDDING FROM OPENAI FOR A married couple in
# GOT EMBEDDING FROM OPENAI FOR Rafe Khatchadorian (
# GOT EMBEDDING FROM OPENAI FOR As a child, Christia
# GOT EMBEDDING FROM OPENAI FOR In the film's spy su
# GOT EMBEDDING FROM OPENAI FOR Max Steel is an in-d
# GOT EMBEDDING FROM OPENAI FOR After dismantling a
# GOT EMBEDDING FROM OPENAI FOR Jeff Gaffney (Zach G
# GOT EMBEDDING FROM OPENAI FOR In 1967 Los Angeles,
# GOT EMBEDDING FROM OPENAI FOR Jonathan and his fra
# GOT EMBEDDING FROM OPENAI FOR In Littleton, Colora
# GOT EMBEDDING FROM OPENAI FOR In 1996, at the 45th
# GOT EMBEDDING FROM OPENAI FOR Harvard University p
# GOT EMBEDDING FROM OPENAI FOR Laura (Alycia Debnam
# GOT EMBEDDING FROM OPENAI FOR Research scientist G
# GOT EMBEDDING FROM OPENAI FOR Ray Kroc is a travel
# GOT EMBEDDING FROM OPENAI FOR In a world of anthro
# GOT EMBEDDING FROM OPENAI FOR Twelve-year-old Conn
# GOT EMBEDDING FROM OPENAI FOR On January 15, 2009,
# GOT EMBEDDING FROM OPENAI FOR On the Polynesian is
# GOT EMBEDDING FROM OPENAI FOR Tom Sherbourne, a tr
# GOT EMBEDDING FROM OPENAI FOR Three years into its
# GOT EMBEDDING FROM OPENAI FOR The film follows the
# GOT EMBEDDING FROM OPENAI FOR Dory, a regal blue t
# GOT EMBEDDING FROM OPENAI FOR In 1996, star athlet
# GOT EMBEDDING FROM OPENAI FOR Shortly after the de
# GOT EMBEDDING FROM OPENAI FOR After surviving the
# GOT EMBEDDING FROM OPENAI FOR Sixteen-year-old asp
# GOT EMBEDDING FROM OPENAI FOR As a result of the B
# GOT EMBEDDING FROM OPENAI FOR Sophie, a 10-year-ol
# GOT EMBEDDING FROM OPENAI FOR A young Charlie Roan
# GOT EMBEDDING FROM OPENAI FOR A Jack Russell Terri
# GOT EMBEDDING FROM OPENAI FOR Brothers Mike and Da
# GOT EMBEDDING FROM OPENAI FOR The story begins in
# GOT EMBEDDING FROM OPENAI FOR During the 1980s, U.
# GOT EMBEDDING FROM OPENAI FOR Physicists Abby Yate
# GOT EMBEDDING FROM OPENAI FOR Twenty years after t
# GOT EMBEDDING FROM OPENAI FOR Scrat, trying to bur
# GOT EMBEDDING FROM OPENAI FOR A supermarket called
# GOT EMBEDDING FROM OPENAI FOR In a textile factory
# GOT EMBEDDING FROM OPENAI FOR After faking his dea
# GOT EMBEDDING FROM OPENAI FOR Rocky, Alex, and Mon
# GOT EMBEDDING FROM OPENAI FOR In feudal Japan, 12-
# GOT EMBEDDING FROM OPENAI FOR A Jewish nobleman, J
# GOT EMBEDDING FROM OPENAI FOR Florence Foster Jenk
# GOT EMBEDDING FROM OPENAI FOR In 2005, David Packo
# GOT EMBEDDING FROM OPENAI FOR In 1977, Pete Healy,
# GOT EMBEDDING FROM OPENAI FOR A decade after he ex
# GOT EMBEDDING FROM OPENAI FOR Tom Brand (Kevin Spa
# GOT EMBEDDING FROM OPENAI FOR In the aftermath of
# GOT EMBEDDING FROM OPENAI FOR High school senior V
# GOT EMBEDDING FROM OPENAI FOR Amy Mitchell (Mila K
# GOT EMBEDDING FROM OPENAI FOR After losing her mot
# GOT EMBEDDING FROM OPENAI FOR After an argument wi
# GOT EMBEDDING FROM OPENAI FOR Muriel Donnelly and
# GOT EMBEDDING FROM OPENAI FOR Years after his movi
# GOT EMBEDDING FROM OPENAI FOR A skyrocketing crime
# GOT EMBEDDING FROM OPENAI FOR Medical researchers
# GOT EMBEDDING FROM OPENAI FOR In 1992, Dr Contrera
# GOT EMBEDDING FROM OPENAI FOR Agatha Weiss arrives
# GOT EMBEDDING FROM OPENAI FOR Five years after the
# GOT EMBEDDING FROM OPENAI FOR Seasoned con-man Nic
# GOT EMBEDDING FROM OPENAI FOR Everly (Salma Hayek)
# GOT EMBEDDING FROM OPENAI FOR Jim White, a footbal
# GOT EMBEDDING FROM OPENAI FOR In the Lower East Si
# GOT EMBEDDING FROM OPENAI FOR Cam (Taylor Lautner)
# GOT EMBEDDING FROM OPENAI FOR Don Champagne (Patri
# GOT EMBEDDING FROM OPENAI FOR A young girl named A
# GOT EMBEDDING FROM OPENAI FOR Haunted by his past,
# GOT EMBEDDING FROM OPENAI FOR Seeking a new start,
# GOT EMBEDDING FROM OPENAI FOR Five days after the
# GOT EMBEDDING FROM OPENAI FOR Jim Terrier (Sean Pe
# GOT EMBEDDING FROM OPENAI FOR A zombie outbreak is
# GOT EMBEDDING FROM OPENAI FOR James King is an ext
# GOT EMBEDDING FROM OPENAI FOR On the run from thei
# GOT EMBEDDING FROM OPENAI FOR In Depression-era No
# GOT EMBEDDING FROM OPENAI FOR Middle-aged couple J
# GOT EMBEDDING FROM OPENAI FOR Cathy sits alone wit
# GOT EMBEDDING FROM OPENAI FOR After defeating Owen
# GOT EMBEDDING FROM OPENAI FOR Bianca is enjoying h
# GOT EMBEDDING FROM OPENAI FOR Lord Charlie Mortdec
# GOT EMBEDDING FROM OPENAI FOR During a mission in
# GOT EMBEDDING FROM OPENAI FOR The story centers on
# GOT EMBEDDING FROM OPENAI FOR Programmer Caleb Smi
# GOT EMBEDDING FROM OPENAI FOR Forty years after th
# GOT EMBEDDING FROM OPENAI FOR Former covert operat
# GOT EMBEDDING FROM OPENAI FOR The film revolves ar
# GOT EMBEDDING FROM OPENAI FOR At a nuclear plant i
# GOT EMBEDDING FROM OPENAI FOR In a small American
# GOT EMBEDDING FROM OPENAI FOR In the deep jungles
# GOT EMBEDDING FROM OPENAI FOR Oscar Vazquez (Carlo
# GOT EMBEDDING FROM OPENAI FOR Jimmy Callahan (Kevi
# GOT EMBEDDING FROM OPENAI FOR A futuristic resort,
# GOT EMBEDDING FROM OPENAI FOR Although living what
# GOT EMBEDDING FROM OPENAI FOR Claire Peterson (Jen
# GOT EMBEDDING FROM OPENAI FOR Franny Ellis (Anne H
# GOT EMBEDDING FROM OPENAI FOR Twenty-one-year-old
# GOT EMBEDDING FROM OPENAI FOR A realm divided betw
# GOT EMBEDDING FROM OPENAI FOR Quinn (Simon Helberg
# GOT EMBEDDING FROM OPENAI FOR Elliot Anderson (Kev
# GOT EMBEDDING FROM OPENAI FOR Five married men sha
# GOT EMBEDDING FROM OPENAI FOR In 2014, 17-year-old
# GOT EMBEDDING FROM OPENAI FOR Nick Wild (Jason Sta
# GOT EMBEDDING FROM OPENAI FOR The drama follows th
# GOT EMBEDDING FROM OPENAI FOR Earth and countless
# GOT EMBEDDING FROM OPENAI FOR In a prologue, the w
# GOT EMBEDDING FROM OPENAI FOR A pirate named Burge
# GOT EMBEDDING FROM OPENAI FOR Jerry (Ryan Reynolds
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR In a series of flash
# GOT EMBEDDING FROM OPENAI FOR After narrowly escap
# GOT EMBEDDING FROM OPENAI FOR Luke Collins (Scott
# GOT EMBEDDING FROM OPENAI FOR Brothers Zach and Gr
# GOT EMBEDDING FROM OPENAI FOR Malcolm Adekanbi and
# GOT EMBEDDING FROM OPENAI FOR Riley Andersen is bo
# GOT EMBEDDING FROM OPENAI FOR Max, a Malinois[4] u
# GOT EMBEDDING FROM OPENAI FOR John Bennett has bee
# GOT EMBEDDING FROM OPENAI FOR Human Resistance lea
# GOT EMBEDDING FROM OPENAI FOR Minions are small, y
# GOT EMBEDDING FROM OPENAI FOR In 1989, scientist H
# GOT EMBEDDING FROM OPENAI FOR Gordon Townsend tell
# GOT EMBEDDING FROM OPENAI FOR At a video-game arca
# GOT EMBEDDING FROM OPENAI FOR In the Vatican, Vica
# GOT EMBEDDING FROM OPENAI FOR In an unnamed South-
# GOT EMBEDDING FROM OPENAI FOR 47 (Rupert Friend) i
# GOT EMBEDDING FROM OPENAI FOR In 1975, James "Whit
# GOT EMBEDDING FROM OPENAI FOR In May 1996 several
# GOT EMBEDDING FROM OPENAI FOR In 2035, the crew of
# GOT EMBEDDING FROM OPENAI FOR In Akron, Ohio, 24-y
# GOT EMBEDDING FROM OPENAI FOR In Buffalo, New York
# GOT EMBEDDING FROM OPENAI FOR When the Little Red-
# GOT EMBEDDING FROM OPENAI FOR In an alternate hist
# GOT EMBEDDING FROM OPENAI FOR In London, ambitious
# GOT EMBEDDING FROM OPENAI FOR In 2002, former Pitt
# GOT EMBEDDING FROM OPENAI FOR Mild-mannered radio
# GOT EMBEDDING FROM OPENAI FOR In 1990, Joy Mangano
# GOT EMBEDDING FROM OPENAI FOR Extreme sport athlet
# GOT EMBEDDING FROM OPENAI FOR In 1823, Hugh Glass
# GOT EMBEDDING FROM OPENAI FOR Single mother Billy
# GOT EMBEDDING FROM OPENAI FOR Awkward, lanky, and
# GOT EMBEDDING FROM OPENAI FOR In 1850, author Herm
# GOT EMBEDDING FROM OPENAI FOR The film alternates
# GOT EMBEDDING FROM OPENAI FOR In the Eastern Europ
# GOT EMBEDDING FROM OPENAI FOR Exactly 100 years af
# GOT EMBEDDING FROM OPENAI FOR Several years before
# GOT EMBEDDING FROM OPENAI FOR Ruthless tycoon and
# GOT EMBEDDING FROM OPENAI FOR In 1933, a child (Xa
# GOT EMBEDDING FROM OPENAI FOR Maya is a toque maca
# GOT EMBEDDING FROM OPENAI FOR After his mother's d
# GOT EMBEDDING FROM OPENAI FOR Christian Longo (Jam
# GOT EMBEDDING FROM OPENAI FOR The story is told th
# GOT EMBEDDING FROM OPENAI FOR After his company cr
# GOT EMBEDDING FROM OPENAI FOR The story of a gay t
# GOT EMBEDDING FROM OPENAI FOR In the seaside town
# GOT EMBEDDING FROM OPENAI FOR One afternoon in San
# GOT EMBEDDING FROM OPENAI FOR Paul Blart (Kevin Ja
# GOT EMBEDDING FROM OPENAI FOR In 1870 Victorian En
# GOT EMBEDDING FROM OPENAI FOR Eric and Amy Bowen a
# GOT EMBEDDING FROM OPENAI FOR Vincent Chase, who s
# GOT EMBEDDING FROM OPENAI FOR Raymond "Ray" Gaines
# GOT EMBEDDING FROM OPENAI FOR Anna Sasaki is an in
# GOT EMBEDDING FROM OPENAI FOR An adult Frank Walke
# GOT EMBEDDING FROM OPENAI FOR Military contractor
# GOT EMBEDDING FROM OPENAI FOR Three years after wi
# GOT EMBEDDING FROM OPENAI FOR Following a nuclear
# GOT EMBEDDING FROM OPENAI FOR In the present-day M
# GOT EMBEDDING FROM OPENAI FOR Rose Cooper is a San
# GOT EMBEDDING FROM OPENAI FOR Susan Cooper is a 40
# GOT EMBEDDING FROM OPENAI FOR Meghan Miles (Banks)
# GOT EMBEDDING FROM OPENAI FOR 11-year-old Annie Pa
# GOT EMBEDDING FROM OPENAI FOR Nate Norman (Jonatha
# GOT EMBEDDING FROM OPENAI FOR Rich is a sex addict
# GOT EMBEDDING FROM OPENAI FOR OsCorp scientist Ric
# GOT EMBEDDING FROM OPENAI FOR In Budapest, Hungary
# GOT EMBEDDING FROM OPENAI FOR Carly Whitten (Camer
# GOT EMBEDDING FROM OPENAI FOR In 2018, in a dystop
# GOT EMBEDDING FROM OPENAI FOR Elliot Brindle, a me
# GOT EMBEDDING FROM OPENAI FOR Dr. Will Caster (Joh
# GOT EMBEDDING FROM OPENAI FOR Spix's Macaws Blu an
# GOT EMBEDDING FROM OPENAI FOR Malcolm Johnson and
# GOT EMBEDDING FROM OPENAI FOR Four-year-old Colton
# GOT EMBEDDING FROM OPENAI FOR Four Asian school gi
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR The film takes place
# GOT EMBEDDING FROM OPENAI FOR On the morning of th
# GOT EMBEDDING FROM OPENAI FOR According to Dread C
# GOT EMBEDDING FROM OPENAI FOR In 2002, Ava, a 14-y
# GOT EMBEDDING FROM OPENAI FOR When a blue collar w
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR In 1993, in the work
# GOT EMBEDDING FROM OPENAI FOR Hazel Grace Lancaste
# GOT EMBEDDING FROM OPENAI FOR Allyson Field is a y
# GOT EMBEDDING FROM OPENAI FOR In 1985, 13-year-old
# GOT EMBEDDING FROM OPENAI FOR When Joel (Rudd) and
# GOT EMBEDDING FROM OPENAI FOR As a young boy, Noah
# GOT EMBEDDING FROM OPENAI FOR Cedric (Kevin Hart)
# GOT EMBEDDING FROM OPENAI FOR In Belleville, New J
# GOT EMBEDDING FROM OPENAI FOR Three MIT students –
# GOT EMBEDDING FROM OPENAI FOR After performing a s
# GOT EMBEDDING FROM OPENAI FOR Five years after the
# GOT EMBEDDING FROM OPENAI FOR Thirteen-year-old Ja
# GOT EMBEDDING FROM OPENAI FOR Two years following
# GOT EMBEDDING FROM OPENAI FOR In 2015, an alien ra
# GOT EMBEDDING FROM OPENAI FOR Mac (Seth Rogen) and
# GOT EMBEDDING FROM OPENAI FOR In 1882, in the town
# GOT EMBEDDING FROM OPENAI FOR Maleficent is a powe
# GOT EMBEDDING FROM OPENAI FOR In a dystopian futur
# GOT EMBEDDING FROM OPENAI FOR Ann Dane, startled b
# GOT EMBEDDING FROM OPENAI FOR Divorcee Lauren Reyn
# GOT EMBEDDING FROM OPENAI FOR Henry Altmann (Robin
# GOT EMBEDDING FROM OPENAI FOR J. B. Bernstein is a
# GOT EMBEDDING FROM OPENAI FOR In 1954, Godzilla, a
# GOT EMBEDDING FROM OPENAI FOR In 2004, Broadway di
# GOT EMBEDDING FROM OPENAI FOR John "Breacher" Whar
# GOT EMBEDDING FROM OPENAI FOR An investigation of
# GOT EMBEDDING FROM OPENAI FOR A misfit group of Ne
# GOT EMBEDDING FROM OPENAI FOR Every ten years for
# GOT EMBEDDING FROM OPENAI FOR Mr. Zimit, a philoso
# GOT EMBEDDING FROM OPENAI FOR Kevin (Billy Zane) a
# GOT EMBEDDING FROM OPENAI FOR In 1943, the Allies
# GOT EMBEDDING FROM OPENAI FOR In the year 2098, Lo
# GOT EMBEDDING FROM OPENAI FOR In Wilmington, Delaw
# GOT EMBEDDING FROM OPENAI FOR Jason (Zac Efron) is
# GOT EMBEDDING FROM OPENAI FOR In 1987, Adele Wheel
# GOT EMBEDDING FROM OPENAI FOR A tugboat pulling a
# GOT EMBEDDING FROM OPENAI FOR In 1795, Dr. Victor
# GOT EMBEDDING FROM OPENAI FOR James Payton is a de
# GOT EMBEDDING FROM OPENAI FOR Laurel and Audrey (Z
# GOT EMBEDDING FROM OPENAI FOR In the fictional tow
# GOT EMBEDDING FROM OPENAI FOR James Burns is in pr
# GOT EMBEDDING FROM OPENAI FOR After the terrorist
# GOT EMBEDDING FROM OPENAI FOR A young couple, Zach
# GOT EMBEDDING FROM OPENAI FOR In 1200 BC ancient G
# GOT EMBEDDING FROM OPENAI FOR Chloe, a single moth
# GOT EMBEDDING FROM OPENAI FOR A man (Sharlto Cople
# GOT EMBEDDING FROM OPENAI FOR In June 2012, high s
# GOT EMBEDDING FROM OPENAI FOR The film opens in a
# GOT EMBEDDING FROM OPENAI FOR Abby Russell is a se
# GOT EMBEDDING FROM OPENAI FOR The story features 1
# GOT EMBEDDING FROM OPENAI FOR Following the events
# GOT EMBEDDING FROM OPENAI FOR Years after a drunke
# GOT EMBEDDING FROM OPENAI FOR Josh Wheaton (Shane
# GOT EMBEDDING FROM OPENAI FOR In a futuristic dyst
# GOT EMBEDDING FROM OPENAI FOR Craig (Pat Healy) is
# GOT EMBEDDING FROM OPENAI FOR Nine years after the
# GOT EMBEDDING FROM OPENAI FOR Tobey Marshall is a
# GOT EMBEDDING FROM OPENAI FOR Doug Varney (Sam Roc
# GOT EMBEDDING FROM OPENAI FOR Mr. Peabody is a gif
# GOT EMBEDDING FROM OPENAI FOR Queen Gorgo of Spart
# GOT EMBEDDING FROM OPENAI FOR John, the last survi
# GOT EMBEDDING FROM OPENAI FOR Alcoholic U.S. Air M
# GOT EMBEDDING FROM OPENAI FOR Recent college gradu
# GOT EMBEDDING FROM OPENAI FOR Brutal gangster Drag
# GOT EMBEDDING FROM OPENAI FOR After her sister Liz
# GOT EMBEDDING FROM OPENAI FOR Jay Wheeler, the "bl
# GOT EMBEDDING FROM OPENAI FOR The film centers aro
# GOT EMBEDDING FROM OPENAI FOR Experienced CIA agen
# GOT EMBEDDING FROM OPENAI FOR When a Former Specia
# GOT EMBEDDING FROM OPENAI FOR In 2028, multination
# GOT EMBEDDING FROM OPENAI FOR Beautiful-but-shy At
# GOT EMBEDDING FROM OPENAI FOR Elise Miller (Grace
# GOT EMBEDDING FROM OPENAI FOR Sixty-five million y
# GOT EMBEDDING FROM OPENAI FOR Aidan Bloom (Zach Br
# GOT EMBEDDING FROM OPENAI FOR Three neighborhood t
# GOT EMBEDDING FROM OPENAI FOR Kate (Hilary Swank)
# GOT EMBEDDING FROM OPENAI FOR Debbie Galardi recal
# GOT EMBEDDING FROM OPENAI FOR Megan (Keira Knightl
# GOT EMBEDDING FROM OPENAI FOR In a post-drought ap
# GOT EMBEDDING FROM OPENAI FOR Petty thief Louis "L
# GOT EMBEDDING FROM OPENAI FOR Philip (Jason Schwar
# GOT EMBEDDING FROM OPENAI FOR In April 1945, the A
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Mary Beth, a museum
# GOT EMBEDDING FROM OPENAI FOR Riggan Thomson is a
# GOT EMBEDDING FROM OPENAI FOR Andrew Neiman is a f
# GOT EMBEDDING FROM OPENAI FOR Boyd Mitchler and hi
# GOT EMBEDDING FROM OPENAI FOR Hank Palmer (Robert
# GOT EMBEDDING FROM OPENAI FOR Before the Renaissan
# GOT EMBEDDING FROM OPENAI FOR The film follows the
# GOT EMBEDDING FROM OPENAI FOR On the outside Zoe R
# GOT EMBEDDING FROM OPENAI FOR Jessica Loren, a roo
# GOT EMBEDDING FROM OPENAI FOR University of Centra
# GOT EMBEDDING FROM OPENAI FOR During the Second Su
# GOT EMBEDDING FROM OPENAI FOR The day of their fif
# GOT EMBEDDING FROM OPENAI FOR In 1967 in Santa Mon
# GOT EMBEDDING FROM OPENAI FOR In the mid-21st cent
# GOT EMBEDDING FROM OPENAI FOR Hiro Hamada is a 14-
# GOT EMBEDDING FROM OPENAI FOR Robert McCall (Denze
# GOT EMBEDDING FROM OPENAI FOR In 1300 BC, Moses, a
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR A Baker (James Corde
# GOT EMBEDDING FROM OPENAI FOR Dave Skylark is the
# GOT EMBEDDING FROM OPENAI FOR In 1958, Margaret Ul
# GOT EMBEDDING FROM OPENAI FOR In 1938 Egypt, a tea
# GOT EMBEDDING FROM OPENAI FOR In Harlem, Manhattan
# GOT EMBEDDING FROM OPENAI FOR New York Times repor
# GOT EMBEDDING FROM OPENAI FOR The different parts
# GOT EMBEDDING FROM OPENAI FOR In June 1995, despit
# GOT EMBEDDING FROM OPENAI FOR The recently widowed
# GOT EMBEDDING FROM OPENAI FOR In Antarctica, three
# GOT EMBEDDING FROM OPENAI FOR In November 2014, Ni
# GOT EMBEDDING FROM OPENAI FOR After being rescued
# GOT EMBEDDING FROM OPENAI FOR In a framing sequenc
# GOT EMBEDDING FROM OPENAI FOR Mary Bee Cuddy (Hila
# GOT EMBEDDING FROM OPENAI FOR Olympic wrestling ch
# GOT EMBEDDING FROM OPENAI FOR Twenty years after t
# GOT EMBEDDING FROM OPENAI FOR Noni Jean is a hot n
# GOT EMBEDDING FROM OPENAI FOR The pregnant Jessabe
# GOT EMBEDDING FROM OPENAI FOR In 1962, con man Che
# GOT EMBEDDING FROM OPENAI FOR In 1970, Shasta Fay
# GOT EMBEDDING FROM OPENAI FOR In the fictional hil
# GOT EMBEDDING FROM OPENAI FOR Oren Little (Douglas
# GOT EMBEDDING FROM OPENAI FOR Six months after the
# GOT EMBEDDING FROM OPENAI FOR A tornado hits the c
# GOT EMBEDDING FROM OPENAI FOR The Kadam family ran
# GOT EMBEDDING FROM OPENAI FOR A teen track runner
# GOT EMBEDDING FROM OPENAI FOR During a visit to Ka
# GOT EMBEDDING FROM OPENAI FOR In 1988, following h
# GOT EMBEDDING FROM OPENAI FOR Get on Up is told us
# GOT EMBEDDING FROM OPENAI FOR In 1928, a globally
# GOT EMBEDDING FROM OPENAI FOR Hercules is the lead
# GOT EMBEDDING FROM OPENAI FOR Jay and Annie Hargro
# GOT EMBEDDING FROM OPENAI FOR Two longtime friends
# GOT EMBEDDING FROM OPENAI FOR On March 21, 2023, t
# GOT EMBEDDING FROM OPENAI FOR Since winning the Wi
# GOT EMBEDDING FROM OPENAI FOR Reformed drug addict
# GOT EMBEDDING FROM OPENAI FOR A Ph.D. student, Ian
# GOT EMBEDDING FROM OPENAI FOR After murdering his
# GOT EMBEDDING FROM OPENAI FOR Paul Maguire and his
# GOT EMBEDDING FROM OPENAI FOR Ten years after the
# GOT EMBEDDING FROM OPENAI FOR In 2002, six-year-ol
# GOT EMBEDDING FROM OPENAI FOR Best friends Wallace
# GOT EMBEDDING FROM OPENAI FOR April O'Neil, a loca
# GOT EMBEDDING FROM OPENAI FOR In Murphysboro, Illi
# GOT EMBEDDING FROM OPENAI FOR The Expendables—led
# GOT EMBEDDING FROM OPENAI FOR The owner of the 20t
# GOT EMBEDDING FROM OPENAI FOR Judd Altman (Jason B
# GOT EMBEDDING FROM OPENAI FOR Following a calamity
# GOT EMBEDDING FROM OPENAI FOR Milo (Hader) writes
# GOT EMBEDDING FROM OPENAI FOR Suki, a young woman
# GOT EMBEDDING FROM OPENAI FOR In 1991, Detective M
# GOT EMBEDDING FROM OPENAI FOR Spencer and Laura Pe
# GOT EMBEDDING FROM OPENAI FOR In Tennessee, a pris
# GOT EMBEDDING FROM OPENAI FOR Bea (Rose Leslie) an
# GOT EMBEDDING FROM OPENAI FOR Three years after sa
# GOT EMBEDDING FROM OPENAI FOR A teenager wakes up
# GOT EMBEDDING FROM OPENAI FOR A young couple, Cath
# GOT EMBEDDING FROM OPENAI FOR Paul, a mechanic, sp
# GOT EMBEDDING FROM OPENAI FOR Mia Hall and her fam
# GOT EMBEDDING FROM OPENAI FOR After his girlfriend
# GOT EMBEDDING FROM OPENAI FOR Ben and George, a sa
# GOT EMBEDDING FROM OPENAI FOR Confronted with the
# GOT EMBEDDING FROM OPENAI FOR Marv regains conscio
# GOT EMBEDDING FROM OPENAI FOR Scarlett Marlowe, a
# GOT EMBEDDING FROM OPENAI FOR Professor Jonathan V
# GOT EMBEDDING FROM OPENAI FOR Emily (Olesya Rulin)
# GOT EMBEDDING FROM OPENAI FOR The story, about los
# GOT EMBEDDING FROM OPENAI FOR Following their succ
# GOT EMBEDDING FROM OPENAI FOR The story opens in 2
# GOT EMBEDDING FROM OPENAI FOR Chip, a young dancer
# GOT EMBEDDING FROM OPENAI FOR Frances Halladay is
# GOT EMBEDDING FROM OPENAI FOR Generation Iron chro
# GOT EMBEDDING FROM OPENAI FOR The film opens in an
# GOT EMBEDDING FROM OPENAI FOR Reggie the turkey ha
# GOT EMBEDDING FROM OPENAI FOR Charley Brewster, Ed
# GOT EMBEDDING FROM OPENAI FOR Princess Elsa of Are
# GOT EMBEDDING FROM OPENAI FOR In 1949 Los Angeles,
# GOT EMBEDDING FROM OPENAI FOR The film depicts the
# GOT EMBEDDING FROM OPENAI FOR Tanner Daniels (Mich
# GOT EMBEDDING FROM OPENAI FOR Following the events
# GOT EMBEDDING FROM OPENAI FOR In the woods, severa
# GOT EMBEDDING FROM OPENAI FOR Nikki (Bening) is a
# GOT EMBEDDING FROM OPENAI FOR Brigadier-General Bo
# GOT EMBEDDING FROM OPENAI FOR Dr. Unger (Embeth Da
# GOT EMBEDDING FROM OPENAI FOR Kate (Olivia Wilde)
# GOT EMBEDDING FROM OPENAI FOR The Barrett family—m
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Victor (Colin Farrel
# GOT EMBEDDING FROM OPENAI FOR A mysterious vehicle
# GOT EMBEDDING FROM OPENAI FOR An ambitious, up-and
# GOT EMBEDDING FROM OPENAI FOR Jon Martello is a yo
# GOT EMBEDDING FROM OPENAI FOR Dracula, a Romanian
# GOT EMBEDDING FROM OPENAI FOR In 2154, Earth is ov
# GOT EMBEDDING FROM OPENAI FOR Ray Breslin is a for
# GOT EMBEDDING FROM OPENAI FOR Washed up former rac
# GOT EMBEDDING FROM OPENAI FOR After failing to get
# GOT EMBEDDING FROM OPENAI FOR In the future, human
# GOT EMBEDDING FROM OPENAI FOR Eva, a masseuse and
# GOT EMBEDDING FROM OPENAI FOR 17 year old Mary Kat
# GOT EMBEDDING FROM OPENAI FOR Ben Logan is an Amer
# GOT EMBEDDING FROM OPENAI FOR Scorch Supernova (Br
# GOT EMBEDDING FROM OPENAI FOR Sixteen-year-old Rus
# GOT EMBEDDING FROM OPENAI FOR Three years after th
# GOT EMBEDDING FROM OPENAI FOR Imogene Duncan (Kris
# GOT EMBEDDING FROM OPENAI FOR After the 74th Hunge
# GOT EMBEDDING FROM OPENAI FOR Thorin and his compa
# GOT EMBEDDING FROM OPENAI FOR Pro baseball player
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR College student Beth
# GOT EMBEDDING FROM OPENAI FOR The human race has b
# GOT EMBEDDING FROM OPENAI FOR In 2005, before Hurr
# GOT EMBEDDING FROM OPENAI FOR 1951 - Having alread
# GOT EMBEDDING FROM OPENAI FOR Wealthy drug dealer
# GOT EMBEDDING FROM OPENAI FOR In the 1970s, succes
# GOT EMBEDDING FROM OPENAI FOR Missouri-born Katie
# GOT EMBEDDING FROM OPENAI FOR In the 1960s, Richar
# GOT EMBEDDING FROM OPENAI FOR In Denver, accountan
# GOT EMBEDDING FROM OPENAI FOR Sam Sotto is a Holly
# GOT EMBEDDING FROM OPENAI FOR The framing device h
# GOT EMBEDDING FROM OPENAI FOR A cave family called
# GOT EMBEDDING FROM OPENAI FOR In 1982, young Alber
# GOT EMBEDDING FROM OPENAI FOR In a near future Los
# GOT EMBEDDING FROM OPENAI FOR FBI agent Sarah Ashb
# GOT EMBEDDING FROM OPENAI FOR When once-up-and-com
# GOT EMBEDDING FROM OPENAI FOR The film is set in 1
# GOT EMBEDDING FROM OPENAI FOR Bernice (Lisa Gay Ha
# GOT EMBEDDING FROM OPENAI FOR In Moscow, Viktor Ch
# GOT EMBEDDING FROM OPENAI FOR Grace "Gracie" Trey
# GOT EMBEDDING FROM OPENAI FOR NASA Space Shuttle E
# GOT EMBEDDING FROM OPENAI FOR In 1931, Nick Carraw
# GOT EMBEDDING FROM OPENAI FOR Justine, a college f
# GOT EMBEDDING FROM OPENAI FOR In 1991, a young Jef
# GOT EMBEDDING FROM OPENAI FOR In their prime, Pitt
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR Teen siblings Hansel
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Abandoned by their f
# GOT EMBEDDING FROM OPENAI FOR The film picks up im
# GOT EMBEDDING FROM OPENAI FOR Johanna Parry (Krist
# GOT EMBEDDING FROM OPENAI FOR In August 2012, a yo
# GOT EMBEDDING FROM OPENAI FOR In July 1985, Dallas
# GOT EMBEDDING FROM OPENAI FOR Nine years have pass
# GOT EMBEDDING FROM OPENAI FOR A high-level cartel
# GOT EMBEDDING FROM OPENAI FOR Pathologically singl
# GOT EMBEDDING FROM OPENAI FOR Following a family d
# GOT EMBEDDING FROM OPENAI FOR A group of refugees
# GOT EMBEDDING FROM OPENAI FOR In the competitive w
# GOT EMBEDDING FROM OPENAI FOR Former pro golfer Wa
# GOT EMBEDDING FROM OPENAI FOR Loveable losers Kate
# GOT EMBEDDING FROM OPENAI FOR In the midst of the
# GOT EMBEDDING FROM OPENAI FOR The title designates
# GOT EMBEDDING FROM OPENAI FOR Dante Graham enlists
# GOT EMBEDDING FROM OPENAI FOR In 1980, Ron Burgund
# GOT EMBEDDING FROM OPENAI FOR In Alabama, Oodie br
# GOT EMBEDDING FROM OPENAI FOR In Gatlin, South Car
# GOT EMBEDDING FROM OPENAI FOR In the wake of the 2
# GOT EMBEDDING FROM OPENAI FOR In 1977, 18-year-old
# GOT EMBEDDING FROM OPENAI FOR Six high school seni
# GOT EMBEDDING FROM OPENAI FOR In the wake of his p
# GOT EMBEDDING FROM OPENAI FOR Minnesotans Scott (J
# GOT EMBEDDING FROM OPENAI FOR The film stars Harry
# GOT EMBEDDING FROM OPENAI FOR In 1978, con artists
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR In late medieval Jap
# GOT EMBEDDING FROM OPENAI FOR Criminals Robert "Bo
# GOT EMBEDDING FROM OPENAI FOR Paramedic Nick Mallo
# GOT EMBEDDING FROM OPENAI FOR In 1841, Solomon Nor
# GOT EMBEDDING FROM OPENAI FOR Friends since high s
# GOT EMBEDDING FROM OPENAI FOR Follow actor J Kimba
# GOT EMBEDDING FROM OPENAI FOR After living in a ps
# GOT EMBEDDING FROM OPENAI FOR In 1945, after sport
# GOT EMBEDDING FROM OPENAI FOR Frankie is a hard-dr
# GOT EMBEDDING FROM OPENAI FOR In the Indian Ocean,
# GOT EMBEDDING FROM OPENAI FOR The film is divided
# GOT EMBEDDING FROM OPENAI FOR Five friends explore
# GOT EMBEDDING FROM OPENAI FOR A content and succes
# GOT EMBEDDING FROM OPENAI FOR Straight-laced Princ
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR Three travelers, Gri
# GOT EMBEDDING FROM OPENAI FOR Ruth Guthrie is walk
# GOT EMBEDDING FROM OPENAI FOR Mia Sullivan (Monica
# GOT EMBEDDING FROM OPENAI FOR Alex Mathis (Greg Gr
# GOT EMBEDDING FROM OPENAI FOR Jack Kerouac, coming
# GOT EMBEDDING FROM OPENAI FOR Inventor Flint Lockw
# GOT EMBEDDING FROM OPENAI FOR Richard Phillips tak
# GOT EMBEDDING FROM OPENAI FOR Alone in her home, M
# GOT EMBEDDING FROM OPENAI FOR In 1970s New York Ci
# GOT EMBEDDING FROM OPENAI FOR Charlie Countryman,
# GOT EMBEDDING FROM OPENAI FOR The movie opens with
# GOT EMBEDDING FROM OPENAI FOR The story begins wit
# GOT EMBEDDING FROM OPENAI FOR "The Cloth" of the t
# GOT EMBEDDING FROM OPENAI FOR In Hollywood, Samant
# GOT EMBEDDING FROM OPENAI FOR Don and Ellie Griffi
# GOT EMBEDDING FROM OPENAI FOR The single-player ca
# GOT EMBEDDING FROM OPENAI FOR A recently widowed s
# GOT EMBEDDING FROM OPENAI FOR In 1980, an annual g
# GOT EMBEDDING FROM OPENAI FOR Abby Ableman is a le
# GOT EMBEDDING FROM OPENAI FOR In 1971, Roger and C
# GOT EMBEDDING FROM OPENAI FOR A bullied teen chef
# GOT EMBEDDING FROM OPENAI FOR In a morgue, BJ has
# GOT EMBEDDING FROM OPENAI FOR When Christian, an L
# GOT EMBEDDING FROM OPENAI FOR Dan Mulligan (Mark R
# GOT EMBEDDING FROM OPENAI FOR Los Angeles Police D
# GOT EMBEDDING FROM OPENAI FOR David (Jonathan Grof
# GOT EMBEDDING FROM OPENAI FOR After his mother, Na
# GOT EMBEDDING FROM OPENAI FOR Sarah (Kate Bosworth
# GOT EMBEDDING FROM OPENAI FOR A drama set in New M
# GOT EMBEDDING FROM OPENAI FOR Quiet teenager Marc
# GOT EMBEDDING FROM OPENAI FOR The movie opens with
# GOT EMBEDDING FROM OPENAI FOR Jasmine Francis (Cat
# GOT EMBEDDING FROM OPENAI FOR Dwight Evans, living
# GOT EMBEDDING FROM OPENAI FOR In Shushan, the capi
# GOT EMBEDDING FROM OPENAI FOR In February 1938, a
# GOT EMBEDDING FROM OPENAI FOR Two of the highest r
# GOT EMBEDDING FROM OPENAI FOR Keith Reynolds is a
# GOT EMBEDDING FROM OPENAI FOR Bridegroom chronicle
# GOT EMBEDDING FROM OPENAI FOR NYPD detective Billy
# GOT EMBEDDING FROM OPENAI FOR In the city of New O
# GOT EMBEDDING FROM OPENAI FOR In 2009, an elderly
# GOT EMBEDDING FROM OPENAI FOR Blynn Lehman, one of
# GOT EMBEDDING FROM OPENAI FOR An expectant couple
# GOT EMBEDDING FROM OPENAI FOR During a sweltering
# GOT EMBEDDING FROM OPENAI FOR After her husband Ma
# GOT EMBEDDING FROM OPENAI FOR Season of Miracles c
# GOT EMBEDDING FROM OPENAI FOR  Walter Mitty is a n
# GOT EMBEDDING FROM OPENAI FOR Salesman Zach Newman
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Sam (Josh Gad) is a
# GOT EMBEDDING FROM OPENAI FOR Grace is the young s
# GOT EMBEDDING FROM OPENAI FOR While drunk, Robert
# GOT EMBEDDING FROM OPENAI FOR John Moon's wife rec
# GOT EMBEDDING FROM OPENAI FOR Charlie Sheen and Li
# GOT EMBEDDING FROM OPENAI FOR In preparation for h
# GOT EMBEDDING FROM OPENAI FOR As the story begins,
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Set entirely inside
# GOT EMBEDDING FROM OPENAI FOR Sutter Keely (Miles
# GOT EMBEDDING FROM OPENAI FOR Debris from a destro
# GOT EMBEDDING FROM OPENAI FOR College students Bri
# GOT EMBEDDING FROM OPENAI FOR Mitchell and Carter,
# GOT EMBEDDING FROM OPENAI FOR In 1961, the financi
# GOT EMBEDDING FROM OPENAI FOR Neil, a seemingly no
# GOT EMBEDDING FROM OPENAI FOR Set during a single
# GOT EMBEDDING FROM OPENAI FOR In 1988, an odd pair
# GOT EMBEDDING FROM OPENAI FOR In suburban Pennsylv
# GOT EMBEDDING FROM OPENAI FOR While walking home f
# GOT EMBEDDING FROM OPENAI FOR In 2014, the New Fou
# GOT EMBEDDING FROM OPENAI FOR Lindsey Lewis and he
# GOT EMBEDDING FROM OPENAI FOR 75-year-old Dr. Nath
# GOT EMBEDDING FROM OPENAI FOR Three years after th
# GOT EMBEDDING FROM OPENAI FOR Five years after Kyr
# GOT EMBEDDING FROM OPENAI FOR Director Salvador Li
# GOT EMBEDDING FROM OPENAI FOR Boston Police Depart
# GOT EMBEDDING FROM OPENAI FOR At Kinetech Labs, an
# GOT EMBEDDING FROM OPENAI FOR In the year 2044, a
# GOT EMBEDDING FROM OPENAI FOR Richie Furst used to
# GOT EMBEDDING FROM OPENAI FOR A terrified woman, K
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR Narrated by a 95-yea
# GOT EMBEDDING FROM OPENAI FOR Two children, Howie
# GOT EMBEDDING FROM OPENAI FOR Released from prison
# GOT EMBEDDING FROM OPENAI FOR In 2259, Captain Jam
# GOT EMBEDDING FROM OPENAI FOR Suzanne is a success
# GOT EMBEDDING FROM OPENAI FOR A paleontologist nam
# GOT EMBEDDING FROM OPENAI FOR About eight years af
# GOT EMBEDDING FROM OPENAI FOR Fourteen-year-old Du
# GOT EMBEDDING FROM OPENAI FOR In February 1961, Ll
# GOT EMBEDDING FROM OPENAI FOR A small-time cannabi
# GOT EMBEDDING FROM OPENAI FOR An office team go on
# GOT EMBEDDING FROM OPENAI FOR President of the Uni
# GOT EMBEDDING FROM OPENAI FOR There is a local myt
# GOT EMBEDDING FROM OPENAI FOR Kantmiss Evershot pr
# GOT EMBEDDING FROM OPENAI FOR In 1987, Jordan Belf
# GOT EMBEDDING FROM OPENAI FOR In 1945, Logan is he
# GOT EMBEDDING FROM OPENAI FOR Former UN employee G
# GOT EMBEDDING FROM OPENAI FOR Eric Harson and his
# GOT EMBEDDING FROM OPENAI FOR Steve Dallas (Owen W
# GOT EMBEDDING FROM OPENAI FOR Scott Weidemeyer (Sa
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR An enigmatic phone c
# GOT EMBEDDING FROM OPENAI FOR Violet (Alexis Blede
# GOT EMBEDDING FROM OPENAI FOR The film takes place
# GOT EMBEDDING FROM OPENAI FOR The film is presente
# GOT EMBEDDING FROM OPENAI FOR On her 18th birthday
# GOT EMBEDDING FROM OPENAI FOR Scott (Ryan Phillipp
# GOT EMBEDDING FROM OPENAI FOR High school senior C
# GOT EMBEDDING FROM OPENAI FOR In a farm in Fernfie
# GOT EMBEDDING FROM OPENAI FOR Offering herself as
# GOT EMBEDDING FROM OPENAI FOR In the late 1800s, a
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR The film starts in a
# GOT EMBEDDING FROM OPENAI FOR Following the events
# GOT EMBEDDING FROM OPENAI FOR Jay Baruchel arrives
# GOT EMBEDDING FROM OPENAI FOR Eons ago, Bor, fathe
# GOT EMBEDDING FROM OPENAI FOR In a suburban San Fe
# GOT EMBEDDING FROM OPENAI FOR The Peeples is an af
# GOT EMBEDDING FROM OPENAI FOR A 17-year-old Brookl
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR During a torrential
# GOT EMBEDDING FROM OPENAI FOR While on the phone w
# GOT EMBEDDING FROM OPENAI FOR Billy, Paddy, Archie
# GOT EMBEDDING FROM OPENAI FOR Joe Toy (Nick Robins
# GOT EMBEDDING FROM OPENAI FOR Paolo, a screenwrite
# GOT EMBEDDING FROM OPENAI FOR First-time filmmaker
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Two underachieving c
# GOT EMBEDDING FROM OPENAI FOR A couple, Jared (Jud
# GOT EMBEDDING FROM OPENAI FOR Sheriff Ray Owens is
# GOT EMBEDDING FROM OPENAI FOR Jimi Lazer, front-ma
# GOT EMBEDDING FROM OPENAI FOR As a young man in th
# GOT EMBEDDING FROM OPENAI FOR This psychological t
# GOT EMBEDDING FROM OPENAI FOR In Detroit in 1978,
# GOT EMBEDDING FROM OPENAI FOR Leigh London is a ta
# GOT EMBEDDING FROM OPENAI FOR In 1933, a boy named
# GOT EMBEDDING FROM OPENAI FOR In Salem, Massachuse
# GOT EMBEDDING FROM OPENAI FOR The movie begins as
# GOT EMBEDDING FROM OPENAI FOR In 1970, 20-year-old
# GOT EMBEDDING FROM OPENAI FOR During the Bosnian W
# GOT EMBEDDING FROM OPENAI FOR Dave Lizewski, bored
# GOT EMBEDDING FROM OPENAI FOR Ellie Klug is a musi
# GOT EMBEDDING FROM OPENAI FOR A suicide bomber det
# GOT EMBEDDING FROM OPENAI FOR After losing her ban
# GOT EMBEDDING FROM OPENAI FOR In 1986, Lorraine La
# GOT EMBEDDING FROM OPENAI FOR Salesmen Billy McMah
# GOT EMBEDDING FROM OPENAI FOR At a New Year's Eve
# GOT EMBEDDING FROM OPENAI FOR Four couples gather
# GOT EMBEDDING FROM OPENAI FOR After climbing a gia
# GOT EMBEDDING FROM OPENAI FOR In the Kingdom of Cl
# GOT EMBEDDING FROM OPENAI FOR After winning $10,00
# GOT EMBEDDING FROM OPENAI FOR Kevin is throwing a
# GOT EMBEDDING FROM OPENAI FOR The film is set in 1
# GOT EMBEDDING FROM OPENAI FOR The film opens in 20
# GOT EMBEDDING FROM OPENAI FOR David Wong, a slacke
# GOT EMBEDDING FROM OPENAI FOR Joe Ransom is a fore
# GOT EMBEDDING FROM OPENAI FOR A backwoods communit
# GOT EMBEDDING FROM OPENAI FOR While visiting his m
# GOT EMBEDDING FROM OPENAI FOR The sequel to Never
# GOT EMBEDDING FROM OPENAI FOR In Afghanistan, Tali
# GOT EMBEDDING FROM OPENAI FOR Billy is sitting in
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Parker (Jason Statha
# GOT EMBEDDING FROM OPENAI FOR In 1905 Kansas, Osca
# GOT EMBEDDING FROM OPENAI FOR In 2013, huge alien
# GOT EMBEDDING FROM OPENAI FOR The film follows Tom
# GOT EMBEDDING FROM OPENAI FOR In 1995, schemer Dan
# GOT EMBEDDING FROM OPENAI FOR Lamb Mannerhelm (Jul
# GOT EMBEDDING FROM OPENAI FOR Adam Cassidy is a lo
# GOT EMBEDDING FROM OPENAI FOR With all the picture
# GOT EMBEDDING FROM OPENAI FOR Parkland weaves toge
# GOT EMBEDDING FROM OPENAI FOR Former Army Ranger M
# GOT EMBEDDING FROM OPENAI FOR An old gangster, wit
# GOT EMBEDDING FROM OPENAI FOR Sara Taylor is a pho
# GOT EMBEDDING FROM OPENAI FOR While in Camp Half-B
# GOT EMBEDDING FROM OPENAI FOR London based journal
# GOT EMBEDDING FROM OPENAI FOR In 1997, Luke Glanto
# GOT EMBEDDING FROM OPENAI FOR Machete Cortez (Dann
# GOT EMBEDDING FROM OPENAI FOR Dusty Crophopper is
# GOT EMBEDDING FROM OPENAI FOR After getting off wo
# GOT EMBEDDING FROM OPENAI FOR Captain Dmitri "Demi
# GOT EMBEDDING FROM OPENAI FOR In 1993, alcoholic a
# GOT EMBEDDING FROM OPENAI FOR New York City teenag
# GOT EMBEDDING FROM OPENAI FOR While investigating
# GOT EMBEDDING FROM OPENAI FOR In Atlanta, Georgia
# GOT EMBEDDING FROM OPENAI FOR With Krypton destabi
# GOT EMBEDDING FROM OPENAI FOR When a businessman's
# GOT EMBEDDING FROM OPENAI FOR Amid aerial footage
# GOT EMBEDDING FROM OPENAI FOR Michael "Mike" Wazow
# GOT EMBEDDING FROM OPENAI FOR Jake Carter (The Miz
# GOT EMBEDDING FROM OPENAI FOR Movie 43 is a series
# GOT EMBEDDING FROM OPENAI FOR While traveling cros
# GOT EMBEDDING FROM OPENAI FOR In 2077, sixty years
# GOT EMBEDDING FROM OPENAI FOR Four stage magicians
# GOT EMBEDDING FROM OPENAI FOR Alicia (Juno Temple)
# GOT EMBEDDING FROM OPENAI FOR The plot of the film
# GOT EMBEDDING FROM OPENAI FOR In Billings, Montana
# GOT EMBEDDING FROM OPENAI FOR Two 14-year-old boys
# GOT EMBEDDING FROM OPENAI FOR It is 2006, and 19-y
# GOT EMBEDDING FROM OPENAI FOR Sandra, manager of a
# GOT EMBEDDING FROM OPENAI FOR Chris Farraday (Mark
# GOT EMBEDDING FROM OPENAI FOR 12-year old Ida Clay
# GOT EMBEDDING FROM OPENAI FOR Zack (Haas) is a you
# GOT EMBEDDING FROM OPENAI FOR A mixed-blood Native
# GOT EMBEDDING FROM OPENAI FOR Eight years after th
# GOT EMBEDDING FROM OPENAI FOR Newly transferred co
# GOT EMBEDDING FROM OPENAI FOR Swanson (Tim Heideck
# GOT EMBEDDING FROM OPENAI FOR In 1760, the Collins
# GOT EMBEDDING FROM OPENAI FOR Casper Galloway, an
# GOT EMBEDDING FROM OPENAI FOR Beth Winter (Keaton)
# GOT EMBEDDING FROM OPENAI FOR Kate is a shark expe
# GOT EMBEDDING FROM OPENAI FOR In February 2012, Se
# GOT EMBEDDING FROM OPENAI FOR Arkansas, November 1
# GOT EMBEDDING FROM OPENAI FOR Teenager Elena Peter
# GOT EMBEDDING FROM OPENAI FOR Will Shaw (Henry Cav
# GOT EMBEDDING FROM OPENAI FOR In the Chatham Islan
# GOT EMBEDDING FROM OPENAI FOR The film is about a
# GOT EMBEDDING FROM OPENAI FOR The Citizen integrat
# GOT EMBEDDING FROM OPENAI FOR Strange electrical c
# GOT EMBEDDING FROM OPENAI FOR The film takes place
# GOT EMBEDDING FROM OPENAI FOR Oscar is the nicknam
# GOT EMBEDDING FROM OPENAI FOR Chris (Jesse McCartn
# GOT EMBEDDING FROM OPENAI FOR In 1987, an 8-year-o
# GOT EMBEDDING FROM OPENAI FOR Darrell, played by a
# GOT EMBEDDING FROM OPENAI FOR Celeste (Rashida Jon
# GOT EMBEDDING FROM OPENAI FOR Young newsparer repo
# GOT EMBEDDING FROM OPENAI FOR Armando Álvarez (Wil
# GOT EMBEDDING FROM OPENAI FOR After a casino heist
# GOT EMBEDDING FROM OPENAI FOR For their vacation,

# %% [markdown]
# ## Plot The Embeddings Using Atlas

# %%
data = movies[["Title", "Genre"]].to_dict("records")

# %%
from nomic import atlas

# %%
project = atlas.map_embeddings(
    embeddings=np.array(plot_embeddings),
    data=data
)
# Out:
# 2023-04-13 20:37:15.632 | INFO     | nomic.project:_create_project:965 - Creating project `flippant-loft` in organization `coltsteele1`
# 2023-04-13 20:37:16.774 | INFO     | nomic.atlas:map_embeddings:100 - Uploading embeddings to Atlas.
# 4it [00:09,  2.34s/it]
# 2023-04-13 20:37:26.243 | INFO     | nomic.project:_add_data:1577 - Upload succeeded.
# 2023-04-13 20:37:26.243 | INFO     | nomic.atlas:map_embeddings:119 - Embedding upload succeeded.
# 2023-04-13 20:37:27.083 | INFO     | nomic.project:create_index:1282 - Created map `flippant-loft` in project `flippant-loft`: https://atlas.nomic.ai/map/5899fca0-27a9-40c7-9a65-0c962306e065/469708b0-74ef-4839-91bc-7186f85f13d7
# 2023-04-13 20:37:27.083 | INFO     | nomic.atlas:map_embeddings:132 - flippant-loft: https://atlas.nomic.ai/map/5899fca0-27a9-40c7-9a65-0c962306e065/469708b0-74ef-4839-91bc-7186f85f13d7

# %% [markdown]
# ## Reccommending Movies By Plot

# %%
from openai.embeddings_utils import distances_from_embeddings, indices_of_nearest_neighbors_from_distances

# %%
def print_recommendations_from_strings(
    strings,
    index_of_source_string,
    k_nearest_neighbors=3,
    model="text-embedding-ada-002"
):
    #Get all of the embeddings
    embeddings = [embedding_from_string(string) for string in strings]
    # get embedding for our specific query string
    query_embedding = embeddings[index_of_source_string]
    # get distances between our embedding and all other embeddings
    distances = distances_from_embeddings(query_embedding, embeddings)
    # get indices of the nearest neighbors
    indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)
    
    query_string = strings[index_of_source_string]
    match_count = 0
    for i in indices_of_nearest_neighbors:
        if query_string == strings[i]:
            continue
        if match_count >= k_nearest_neighbors:
            break
        match_count += 1
        print(f"Found {match_count} closest match: ")
        print(f"Distance of: {distances[i]} ")
        print(strings[i])

# %%
print_recommendations_from_strings(movie_plots, 2)
# Out:
# Found 1 closest match:
# Distance of: 0.13645957078907822
# In the near future, the unmanned Pilgrim 7 space probe returns from Mars to Earth orbit with soil samples potentially containing evidence of extraterrestrial life. The probe is captured and its samples retrieved by the International Space Station and its six-member crew. Exobiologist Hugh Derry, who is paralyzed from the waist down, revives a dormant cell from the sample, which quickly grows into a multi-celled organism that American school children name "Calvin". Hugh realizes that Calvin's cells can change their specialisation, acting as muscle, sensor, and neuron cells all at once.
# An accident in the lab causes Calvin to become dormant; Hugh attempts to revive Calvin with electric shocks, but Calvin immediately becomes hostile and attacks Hugh, crushing his hand. While Hugh lies unconscious from Calvin's attack, Calvin uses Hugh's electric shock tool to escape its enclosure; now free in the laboratory, Calvin devours a lab rat by absorbing it, growing in size. Engineer Rory Adams enters the lab to rescue Hugh; he is locked in by fellow crew member and physician David Jordan, however, to keep Calvin contained. Calvin latches onto Rory's leg; after Rory unsuccessfully attacks Calvin with a portable rocket thruster, Calvin enters his mouth, devouring his organs from the inside and killing him. Emerging from Rory's mouth even larger, Calvin escapes through a fire-control vent.
# Finding their communication with Earth cut off due to overheating of the communication systems, ISS commander Ekaterina Golovkina performs a space walk to find and fix the problem. She discovers that Calvin has breached the ISS's cooling system; soon after, Calvin attacks her, rupturing her spacesuit's water coolant system in the process and causing the water in the system to fill her suit. She blindly makes her way back to the airlock; however, she and the crew realize that if she re-enters, Calvin will also be able to re-enter the ISS. Hence, she refuses to open the hatch and stops David from helping her do so; this keeps Calvin out of the station for the time being but also causes her to drown and die in her spacesuit.
# Calvin then attempts to re-enter the station through its maneuvering thrusters. The crew try to fire the thrusters to blast Calvin away from the spacecraft, but their attempts fail, using up too much fuel and causing the ISS to enter a decaying orbit where it will burn up in Earth's atmosphere. Pilot Sho Murakami informs the crew that they need to use the station's remaining fuel to get back into a safe orbit, although this allows Calvin to re-enter the station. The crew plan to make Calvin dormant by sealing themselves into one module and venting the atmosphere from the rest of the station.
# After the remaining crew finalize preparations to do so, Hugh enters cardiac arrest. The crew then discover that Calvin has been feeding off of Hugh's paralyzed leg. Calvin attacks the remainder of the crew; Sho seals himself in a sleeping pod. As Calvin attempts to break its glass, David and the quarantine officer Miranda North use Hugh's corpse as bait to lure Calvin away from Sho and trap it in another module to deprive it of oxygen. Having received a distress call prior to the damage to the ISS's communication system, Earth sends a Soyuz spacecraft to the station as a fail-safe plan to push the station into deep space. Believing the Soyuz to be on a rescue mission for the ISS crew, Sho leaves his pod and moves to board it, forcing open its hatch; Calvin then attacks him and the Soyuz crew, causing the craft's docking mechanism to fail and resulting in the capsule crashing into the ISS, killing Sho and the Soyuz crew and causing the ISS to once again enter a decaying orbit.
# The only two remaining survivors, David and Miranda, aware that Calvin could survive re-entry, plan for David to lure Calvin into one of the two remaining escape pods attached to the ISS for David to manually pilot the pod into deep space, isolating Calvin and allowing Miranda to return to Earth in the second pod. David manages to lure Calvin into his pod while Miranda enters her pod; as they simultaneously undock their pods from the ISS, one of the pods hits debris and is damaged, veering off course. In David's pod, Calvin attacks him as he struggles to manually pilot the pod; in Miranda's pod, she records a black box message in case of her death during re-entry informing the world of her colleagues' deaths and not to trust Calvin nor any extraterrestrial life from Mars as well as to destroy Calvin at any cost should he make his way to Earth.
# The two pods separate, one earthbound, the other spiraling away from Earth. The earthbound pod lands in the ocean; two nearby Vietnamese fishermen approach it. As they look into the pod, it is revealed to be David's, the astronaut now encased in a web-like substance. Meanwhile, Miranda's pod's navigation system fails due to damage sustained from the debris, sending her flying away from Earth out of control, much to her horror. On Earth, despite David attempting to warn the fishermen, the fishermen open the pod's hatch. Meanwhile, more boats arrive.
# Found 2 closest match:
# Distance of: 0.15542940005168138
# Waking inside a laboratory on an airship, a man recalls bullies from his childhood. A scientist, Estelle (Haley Bennett), greets him and says his name is Henry, she is his wife, and that he has been revived from an accident that left him amnesiac and mute. After she replaces a missing arm and leg with cybernetic prostheses, mercenaries led by the psychokinetic Akan (Danila Kozlovsky) raid the ship, claiming all of Estelle's research is Akan's corporate property. He kills Estelle's scientists before attempting to murder Henry, but Henry and Estelle flee in an escape pod, landing in Moscow. Estelle is abducted by the mercenaries, who try to kill Henry.
# Henry is rescued by a mysterious man, Jimmy (Sharlto Copley), who informs him that his cybernetic implants are running out of power, which will kill him if he can't recharge. Jimmy is killed by corrupt cops bought out by Akan, and Henry is forced to fight his way through both cops and mercenaries, sneaking onto a bus. He is joined by Jimmy — not dead, now an alcoholic, odorous bum — who informs him that one of Akan's associates, Slick Dimitry, has a cybernetic charging pump implanted, which Henry needs to recharge. The two are attacked by a flamethrower-wielding goon. Jimmy is incinerated, but Henry escapes, locating and chasing Dimitry throughout Moscow before capturing him; just as Dimitry promises him information, he is killed by a sniper. Henry removes the pump and receives a call from Jimmy, who directs Henry to a brothel.
# Henry meets two more versions of Jimmy — a cocaine-addicted lothario and a shy, awkward geek — who replace his pump. The brothel is attacked by Akan's forces. Henry fights his way through, but encounters Akan, who taunts him with Estelle's kidnapping, revealing she is being transported by an armored convoy. Akan hurls Henry out of the brothel.
# Outside, Henry encounters another Jimmy — now a marijuana-obsessed hippie-biker — who transports him to Akan's convoy. Henry finds Estelle - and Akan, who (seemingly) kills him and buries him in the woods.
# Jimmy finds and resuscitates Henry, only to be shelled by a tank. After killing the tank crew, fending off a helicopter, and failing to ride a runaway horse, Henry finds another Jimmy — a gruff sniper in a ghillie suit — who leads him to an abandoned hotel, where Jimmy is headquartered in a hidden laboratory. Jimmy and Henry encounter a number of policemen surrounding a girl. They are in the process of forcing her to perform oral sex on one of the cops. Henry kills them all. Here, the real Jimmy — a quadriplegic scientist — reveals his motive for helping Henry: revenge against Akan, who crippled him after his own cyborg super-soldiers failed. He reveals the other Jimmys are dormant clones that he can control, through which he lives a vice-filled life. The clones attack Henry after Jimmy realizes that Henry has been unknowingly broadcasting his location to Akan, with a strike force closing in. Fending off Jimmy, Henry convinces him to help. Henry and the clones of Jimmy — ranging from a punk rocker to a posh WWII Colonel — fight their way out, killing the force by collapsing the laboratory on them.
# Jimmy and Henry drive to Akan's headquarters. They fight their way into an elevator, but Jimmy is mortally wounded. Before dying, Jimmy thanks Henry for being the closest thing to a friend he had, and removes a memory blocker, gradually restoring Henry's memories. Henry fights his way to the highest floor, where he is greeted by Akan, revealing an army of cyborg super-soldiers being fed Henry's memories. One such soldier fights Henry, followed by the rest of the army, chasing Henry to the roof.
# Henry wipes out the entire army. Akan arrives and severely wounds Henry. Shortly after, Estelle arrives as well. In reality, Estelle was Akan's wife, forming an elaborate ruse to field-test Henry and use his memories to manipulate cyborg soldiers into doing anything to "rescue" their "wife" — specifically, terrorist attacks and world domination as Akan's loyal slaves. The two leave Henry for dead, leaving in a helicopter. Henry blacks out, but is energized by an emerging memory of his father (Tim Roth) encouraging him to fight back against the childhood bullies seen in the intro. Henry manages to reach Akan, decapitating him with his cybernetic eyestalk. He jumps onto Estelle's helicopter, presenting her Akan's head. Estelle shoots him, but the bullet ricochets off his cybernetic hand and wounds her, leaving her hanging from the helicopter. Estelle pleads with Henry to save her, but Henry slams the door, sending her falling to her death.
# Mid-credits, an answering machine message from Jimmy is heard, telling Henry there is "one more thing" to do.
# Found 3 closest match:
# Distance of: 0.15794912732933353
# In 2077, sixty years after a war with extraterrestrials that devastated Earth, humanity has relocated to Saturn's moon Titan via a giant space station called the Tet. Gigantic offshore fusion energy generators drain Earth's oceans to power the colonies on Titan.
# Led by mission controller Sally and guided by his housemate and communications partner Victoria "Vika" Olsen, "Tech-49" Jack Harper regularly leaves his tower post to repair downed combat drones that guard the regions and generators against the alien scavengers. Although his memory has been wiped, he has had recurring dreams and visions of being on the observation deck of the Empire State Building with a dark-haired woman. He also collects the occasional artifact that he finds from humanity's past. Vika is concerned about Jack's curiosity, questioning whether they are still “an effective team,” and encouraging him to do his job, so they can join the others on Titan soon.
# After scavengers destroy a generator, Jack discovers that they have been using the Empire State Building's antenna to transmit coordinates to outer space. While taking a break at his secret lake house retreat, he watches a crash-landing module of a pre-war spacecraft called the Odyssey. Thinking that the ship contains aliens, he investigates, only to find humans in stasis chambers. One of the humans is the woman from his dreams. Jack protects her chamber from a drone that destroys the others, and later, revives the woman, Julia Rusakova, who makes Vika instinctively jealous. Jack and Julia return to recover her flight recorder, but are captured by the scavengers. They are taken to their headquarters at the Raven Rock Mountain Complex, and the scavengers are revealed to be human survivors.
# Their leader, Malcolm Beech, wants Jack to reprogram their captured drone to carry nuclear fuel cells to blow up the Tet; he has sensed Jack is different because of the latter's hobby of collecting relics. Although Jack refuses, Beech releases them to seek the truth beyond the boundaries of the forbidden radiation zone. When they reach the Empire State Building, Julia reveals that she is his wife. Jack then remembers that he proposed to her there. Julia recalls that she was on a mission to Titan when they were diverted to investigate an alien presence.
# When the two return to Jack's tower, Vika refuses them entry, and reports her findings to Sally, saying they are "no longer an effective team." Sally acknowledges this, but activates a drone that kills Vika before Julia shoots it down. Jack and Julia escape in his ship, but are shot down by other pursuing drones. The two eject into the radiation zone, which turns out not to be radioactive. Jack discovers another ship with a technician trying to repair a downed drone, and is shocked to see that the tech is a clone of himself who goes by "Tech-52". The clone also is shocked to see Julia. Jack battles and incapacitates his clone, but Julia is accidentally shot. After flying to Tech-52's tower, and discovering an inquisitive Vika clone, he returns to treat Julia then take her to the lake house.
# At the scavenger base, Beech reveals to Jack and Julia that the Tet was an alien artificial intelligence that destroyed the Moon, causing massive devastation to the planet, and invaded Earth with thousands of Jack clones and drones to wipe out the human race, extracting all of the planet's natural resources before moving on. As Jack repairs the captured drone, the base is attacked by other drones, gravely injuring Beech, and ruining the captured drone except for its fuel cells. Jack agrees to deliver Julia to Sally through the stasis chamber. On the way to the Tet, Jack listens to the Odyssey's flight recorder, and learns that he was the mission commander, Vika was his co-pilot, and Sally was their mission controller from Earth. When the Tet started to draw in their ship, Jack jettisoned the pod of stasis chambers containing the crew members (including Julia) leaving himself and Vika to be captured.
# Back in the present, Jack enters a large room full of capsules of Jack and Vika clones. He shows Tet the stasis chamber, but it carries Beech and the fuel cells, which they then detonate, killing themselves and destroying the Tet. On Earth, Julia awakens at the lake house. Three years later, she and her daughter meet the resistance members and "Tech-52" Jack, who has also recovered his memories.
